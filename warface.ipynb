# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnu-777/python-openCV/blob/main/warface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
img=cv2.imread('/Warface 3.jpg',0)
cv2_imshow(img)
print(img.shape)
# Out:
# <PIL.Image.Image image mode=L size=3840x2160 at 0x7F34CFF467D0>
# (2160, 3840)
